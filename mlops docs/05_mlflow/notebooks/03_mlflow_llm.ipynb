# %%
import warnings
warnings.filterwarnings('ignore', category=UserWarning)

from langchain.chat_models import init_chat_model
from langchain.chains import LLMChain
from langchain.prompts import ChatPromptTemplate
from pydantic import BaseModel
import mlflow
import os

# %%
#mlflow.langchain.autolog()  # For LangChain

# %%
from getpass import getpass

os.environ['GOOGLE_API_KEY'] = getpass("Enter your Google API key: ")
print("Key loaded!")

# %%
model = init_chat_model(model="gemini-2.5-flash", model_provider="google_genai", max_tokens=500)

# %%
class ContactInfo(BaseModel):
    name: str
    email: str
    phone: str

# %%
# Create a prompt template for contact extraction
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are an expert at extracting contact information from text. Extract the name, email, and phone number and return them in JSON format with keys: name, email, phone."),
    ("human", "{text}")
])

# Create a Chain that MLflow can log
contact_chain = LLMChain(llm=model, prompt=prompt)
# Out:
# /tmp/ipykernel_78098/1923082509.py:8: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   contact_chain = LLMChain(llm=model, prompt=prompt)

# %%
mlflow.set_experiment("Cooking Assistant")
# Out:
# <Experiment: artifact_location='file:///home/train/vbo-mlops/05_mlflow/notebooks/mlruns/578621774246543415', creation_time=1764471076350, experiment_id='578621774246543415', last_update_time=1764471076350, lifecycle_stage='active', name='Cooking Assistant', tags={}>

# %%
test_text = "John Doe, john@example.com, (555) 123-4567"

# %%
with mlflow.start_run():
    # Log the LLMChain which MLflow supports
    model_info = mlflow.langchain.log_model(
        contact_chain, 
        name="contact_extraction_chain",
        input_example={"text": test_text}
    )
    
    # Test the chain using invoke (not deprecated)
    result = contact_chain.invoke({"text": test_text})
    print(f"Extraction result: {result}")
    
    # Log the result
    mlflow.log_text(str(result), "extraction_output.txt")

# %%
loaded_model = mlflow.pyfunc.load_model(model_info.model_uri)

dish1 = loaded_model.predict({"recipe": "boeuf bourginon", "customer_count": "4"})

print(dish1[0])
# Out:
# ---------------------------------------------------------------------------
# ConstructorError                          Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 loaded_model = mlflow.pyfunc.load_model(model_info.model_uri)
#       3 dish1 = loaded_model.predict({"recipe": "boeuf bourginon", "customer_count": "4"})
#       5 print(dish1[0])
#
# File ~/vbo-mlops/uv_env/.venv/lib64/python3.12/site-packages/mlflow/tracing/provider.py:567, in trace_disabled.<locals>.wrapper(*args, **kwargs)
#     565 try:
#     566     is_func_called = True
# --> 567     result = f(*args, **kwargs)
#     568 finally:
#     569     enable()
#
# File ~/vbo-mlops/uv_env/.venv/lib64/python3.12/site-packages/mlflow/pyfunc/__init__.py:1173, in load_model(model_uri, suppress_warnings, dst_path, model_config)
#    1171         model_impl = importlib.import_module(conf[MAIN])._load_pyfunc(data_path, model_config)
#    1172     else:
# -> 1173         model_impl = importlib.import_module(conf[MAIN])._load_pyfunc(data_path)
#    1174 except ModuleNotFoundError as e:
#    1175     # This error message is particularly for the case when the error is caused by module
#    1176     # "databricks.feature_store.mlflow_model". But depending on the environment, the offending
#    1177     # module might be "databricks", "databricks.feature_store" or full package. So we will
#    1178     # raise the error with the following note if "databricks" presents in the error. All non-
#    1179     # databricks module errors will just be re-raised.
#    1180     if conf[MAIN] == _DATABRICKS_FS_LOADER_MODULE and e.name.startswith("databricks"):
#
# File ~/vbo-mlops/uv_env/.venv/lib64/python3.12/site-packages/mlflow/langchain/model.py:842, in _load_pyfunc(path, model_config)
#     836 def _load_pyfunc(path: str, model_config: dict[str, Any] | None = None):
#     837     """Load PyFunc implementation for LangChain. Called by ``pyfunc.load_model``.
#     838
#     839     Args:
#     840         path: Local filesystem path to the MLflow Model with the ``langchain`` flavor.
#     841     """
# --> 842     return _LangChainModelWrapper(_load_model_from_local_fs(path, model_config), path)
#
# File ~/vbo-mlops/uv_env/.venv/lib64/python3.12/site-packages/mlflow/langchain/model.py:881, in _load_model_from_local_fs(local_model_path, model_config_overrides)
#     879         _clear_dependencies_schemas()
#     880 else:
# --> 881     model = _load_model(local_model_path, flavor_conf)
#     882 # set active model after model loading since experiment ID might be set
#     883 # in the model loading process
#     884 _update_active_model_id_based_on_mlflow_model(mlflow_model)
#
# File ~/vbo-mlops/uv_env/.venv/lib64/python3.12/site-packages/mlflow/langchain/utils/logging.py:591, in patch_langchain_type_to_cls_dict.<locals>.wrapper(*args, **kwargs)
#     588     module.get_type_to_cls_dict = _patched_get_type_to_cls_dict(originals[name])
#     590 try:
# --> 591     return func(*args, **kwargs)
#     592 except ValueError as e:
#     593     if m := _CHAT_MODELS_ERROR_MSG.search(str(e)):
#
# File ~/vbo-mlops/uv_env/.venv/lib64/python3.12/site-packages/mlflow/langchain/model.py:634, in _load_model(local_model_path, flavor_conf)
#     632     model = _load_runnables(local_model_path, flavor_conf)
#     633 elif model_load_fn == _BASE_LOAD_KEY:
# --> 634     model = _load_base_lcs(local_model_path, flavor_conf)
#     635 else:
#     636     raise mlflow.MlflowException(
#     637         "Failed to load LangChain model. Unknown model type: "
#     638         f"{flavor_conf.get(_MODEL_TYPE_KEY)}"
#     639     )
#
# File ~/vbo-mlops/uv_env/.venv/lib64/python3.12/site-packages/mlflow/langchain/utils/logging.py:525, in _load_base_lcs(local_model_path, conf)
#     523         model = _patch_loader(load_chain)(lc_model_path, **kwargs)
#     524 elif agent_path is None and tools_path is None:
# --> 525     model = _patch_loader(load_chain)(lc_model_path)
#     526 else:
#     527     from langchain.agents import initialize_agent
#
# File ~/vbo-mlops/uv_env/.venv/lib64/python3.12/site-packages/langchain_core/_api/deprecation.py:193, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     191     warned = True
#     192     emit_warning()
# --> 193 return wrapped(*args, **kwargs)
#
# File ~/vbo-mlops/uv_env/.venv/lib64/python3.12/site-packages/langchain/chains/loading.py:707, in load_chain(path, **kwargs)
#     701     msg = (
#     702         "Loading from the deprecated github-based Hub is no longer supported. "
#     703         "Please use the new LangChain Hub at https://smith.langchain.com/hub "
#     704         "instead."
#     705     )
#     706     raise RuntimeError(msg)
# --> 707 return _load_chain_from_file(path, **kwargs)
#
# File ~/vbo-mlops/uv_env/.venv/lib64/python3.12/site-packages/langchain/chains/loading.py:720, in _load_chain_from_file(file, **kwargs)
#     718 elif file_path.suffix.endswith((".yaml", ".yml")):
#     719     with file_path.open() as f:
# --> 720         config = yaml.safe_load(f)
#     721 else:
#     722     msg = "File type must be json or yaml"
#
# File ~/vbo-mlops/uv_env/.venv/lib64/python3.12/site-packages/yaml/__init__.py:125, in safe_load(stream)
#     117 def safe_load(stream):
#     118     """
#     119     Parse the first YAML document in a stream
#     120     and produce the corresponding Python object.
#    (...)    123     to be safe for untrusted input.
#     124     """
# --> 125     return load(stream, SafeLoader)
#
# File ~/vbo-mlops/uv_env/.venv/lib64/python3.12/site-packages/yaml/__init__.py:81, in load(stream, Loader)
#      79 loader = Loader(stream)
#      80 try:
# ---> 81     return loader.get_single_data()
#      82 finally:
#      83     loader.dispose()
#
# File ~/vbo-mlops/uv_env/.venv/lib64/python3.12/site-packages/yaml/constructor.py:51, in BaseConstructor.get_single_data(self)
#      49 node = self.get_single_node()
#      50 if node is not None:
# ---> 51     return self.construct_document(node)
#      52 return None
#
# File ~/vbo-mlops/uv_env/.venv/lib64/python3.12/site-packages/yaml/constructor.py:60, in BaseConstructor.construct_document(self, node)
#      58     self.state_generators = []
#      59     for generator in state_generators:
# ---> 60         for dummy in generator:
#      61             pass
#      62 self.constructed_objects = {}
#
# File ~/vbo-mlops/uv_env/.venv/lib64/python3.12/site-packages/yaml/constructor.py:413, in SafeConstructor.construct_yaml_map(self, node)
#     411 data = {}
#     412 yield data
# --> 413 value = self.construct_mapping(node)
#     414 data.update(value)
#
# File ~/vbo-mlops/uv_env/.venv/lib64/python3.12/site-packages/yaml/constructor.py:218, in SafeConstructor.construct_mapping(self, node, deep)
#     216 if isinstance(node, MappingNode):
#     217     self.flatten_mapping(node)
# --> 218 return super().construct_mapping(node, deep=deep)
#
# File ~/vbo-mlops/uv_env/.venv/lib64/python3.12/site-packages/yaml/constructor.py:143, in BaseConstructor.construct_mapping(self, node, deep)
#     140     if not isinstance(key, collections.abc.Hashable):
#     141         raise ConstructorError("while constructing a mapping", node.start_mark,
#     142                 "found unhashable key", key_node.start_mark)
# --> 143     value = self.construct_object(value_node, deep=deep)
#     144     mapping[key] = value
#     145 return mapping
#
# File ~/vbo-mlops/uv_env/.venv/lib64/python3.12/site-packages/yaml/constructor.py:100, in BaseConstructor.construct_object(self, node, deep)
#      98             constructor = self.__class__.construct_mapping
#      99 if tag_suffix is None:
# --> 100     data = constructor(self, node)
#     101 else:
#     102     data = constructor(self, tag_suffix, node)
#
# File ~/vbo-mlops/uv_env/.venv/lib64/python3.12/site-packages/yaml/constructor.py:427, in SafeConstructor.construct_undefined(self, node)
#     426 def construct_undefined(self, node):
# --> 427     raise ConstructorError(None, None,
#     428             "could not determine a constructor for the tag %r" % node.tag,
#     429             node.start_mark)
#
# ConstructorError: could not determine a constructor for the tag 'tag:yaml.org,2002:python/tuple'
#   in "/home/train/vbo-mlops/05_mlflow/notebooks/mlruns/578621774246543415/models/m-5515123795f44d7faeb4c18d16f84217/artifacts/model.yaml", line 8, column 21

# %%
# Out:
# name='John Doe' email='john@example.com' phone='(555) 123-4567'
